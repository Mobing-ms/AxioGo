# %% [markdown]
# ## Notebook for learning purpose (Not part of the project)

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
import os

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model = init_chat_model("google_genai:gemini-3.1-flash-lite")
response = model.invoke("Do you have token limit")
response.text
# Out:
# 'Yes, I do have token limits. These limits apply to both the input (what you send to me) and the output (what I generate for you).\n\nHere is how it works:\n\n### 1. Output (Generation) Limit\nThere is a maximum number of tokens I can generate in a single response. If a request is very long (like asking for a full book or a massive codebase), I may "cut off" before finishing. If this happens, you can usually just type **"continue"** to have me pick up where I left off.\n\n### 2. Input (Context Window) Limit\nI have a "context window," which is the total amount of text I can "remember" or process at one time during a conversation. This includes:\n*   The system instructions.\n*   Your current prompt.\n*   The entire history of our conversation so far.\n\nIf our conversation exceeds the context window, I will begin to "forget" the earliest parts of the chat to make room for new information.\n\n### Why do these limits exist?\n*   **Computational Resources:** Processing large amounts of text requires significant memory and processing power.\n*   **Latency:** The larger the request, the longer it takes to generate a response.\n*   **Model Architecture:** The specific version of the model you are using has a hard-coded limit set by its developers.\n\n### Helpful Tips:\n*   **If you have a huge document:** If you are trying to paste a very long text, it is better to upload it as a file (if the interface allows) or break it into smaller segments.\n*   **If the conversation gets too long:** If you notice I\'m starting to lose track of details from the beginning of our chat, it means the context window is full. Starting a **new chat session** is usually the best way to reset and maintain high performance.\n\n**Do you have a specific task in mind that you are worried might be too long?** I can help you figure out the best way to approach it.'
